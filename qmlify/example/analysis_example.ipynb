# %%
import analysis
import os
import numpy as np

# %%
all_sims = []

for results_file in os.listdir('../../nn-endstates/tyk2_hrestraints/results/'):
    try:
        results = np.load(f'../../nn-endstates/tyk2_hrestraints/results/{results_file}',allow_pickle=True)
        all_sims.append(results)
    except IsADirectoryError:
        continue

# %%
ani_results = np.load('../../nn-endstates/tyk2_hrestraints/ANI2_ligand_dg_corrections.kT.npz',allow_pickle=True)
ani_results = ani_results['arr_0'].flatten()[0]

# %%
experimental = [-9.540000 , -10.940000 , -8.980000 , -11.310000 , -9.210000 , -8.260000 , -10.980000 , -7.750000 , -9.560000 , -7.420000 , -11.280000 , -9 , -9.700000 , -11.700000 , -9.780000 , -10.530000]

# %%
analysis.analyze_mlmm(all_sims, ani_results, experimental=experimental, experimental_error=0.18)
